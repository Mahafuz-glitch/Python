# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/Users/admin/Downloads/train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
df1=pd.read_csv("/Users/admin/Downloads/googleplaystore.csv")

# %%
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df1['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#lambda function :

# %%
#def fun_name(args):
    #code
    

#lambda args : expression


def cube(x):
    return x*x*x


a=lambda y : y*y*y

# %%
cube(4)
# Out:
# 64

# %%
a(3)
# Out:
# 27

# %%
list1=[45,12,45,89,77,43,67,22,86]

# %%
#filter,map,reduce
'''
def even(x):
    if x%2==0:
        return x
'''

newlist=list(filter(lambda x : x%2==0 , list1))

# %%
newlist
# Out:
# [12, 22, 86]

# %%
list(map(lambda x : x/2 , list1))
# Out:
# [22.5, 6.0, 22.5, 44.5, 38.5, 21.5, 33.5, 11.0, 43.0]

# %%
import functools

# %%
list1=[45,12,45,89,77,43,67,22,86]
functools.reduce(lambda x,y : x+y,list1)
# Out:
# 486

# %%
df1['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
x='$3.49'

# %%
x.replace('$','')
# Out:
# '3.49'

# %%
df1['Price']=df1['Price'].apply(lambda x : str(x).replace('$','')  if '$' in str(x) else x  )

# %%
df1['Price'].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        'Everyone', '1.20', '1.04'], dtype=object)

# %%
df1['Price']=df1['Price'].replace("Everyone","0")

# %%
df1['Price'].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
df1['Price']=df1['Price'].apply(lambda x : float(x))

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %%
df1['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %%
df1['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
df.rename(columns={
    'Sex':'Gender',
    'Pclass':'PassengerClass'
})
# Out:
#      PassengerId  Survived  PassengerClass  \
# 0              1         0               3
# 1              2         1               1
# 2              3         1               3
# 3              4         1               1
# 4              5         0               3
# ..           ...       ...             ...
# 886          887         0               2
# 887          888         1               1
# 888          889         0               3
# 889          890         1               1
# 890          891         0               3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.sort_values(by=['Age'])
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values(by=['Age'],ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values(by=['Pclass','Age'])
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 305          306         1       1            Allison, Master. Hudson Trevor
# 297          298         0       1              Allison, Miss. Helen Loraine
# 445          446         1       1                 Dodge, Master. Washington
# 802          803         1       1       Carter, Master. William Thornton II
# 435          436         1       1                 Carter, Miss. Lucile Polk
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.groupby(['Sex']).size()
# Out:
# Sex
# female    314
# male      577
# dtype: int64

# %%
df.groupby(['Sex'])['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
df.groupby(['Pclass','Sex']).size()
# Out:
# Pclass  Sex
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# dtype: int64

# %%
df.groupby(['Pclass','Sex']).size().unstack()
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
df.groupby(['Pclass','Sex'])['Age'].mean()
# Out:
# Pclass  Sex
# 1       female    34.611765
#         male      41.281386
# 2       female    28.722973
#         male      30.740707
# 3       female    21.750000
#         male      26.507589
# Name: Age, dtype: float64

# %%
df.groupby(['Pclass','Sex'])['Age'].mean().unstack()
# Out:
# Sex        female       male
# Pclass
# 1       34.611765  41.281386
# 2       28.722973  30.740707
# 3       21.750000  26.507589

# %%
df.sample(50)
# Out:
#      PassengerId  Survived  Pclass  \
# 731          732         0       3
# 271          272         1       3
# 709          710         1       3
# 323          324         1       2
# 815          816         0       1
# 719          720         0       3
# 718          719         0       3
# 788          789         1       3
# 660          661         1       1
# 436          437         0       3
# 724          725         1       1
# 14            15         0       3
# 567          568         0       3
# 386          387         0       3
# 251          252         0       3
# 392          393         0       3
# 7              8         0       3
# 452          453         0       1
# 142          143         1       3
# 612          613         1       3
# 454          455         0       3
# 570          571         1       2
# 337          338         1       1
# 50            51         0       3
# 424          425         0       3
# ...

# %%
df.sample(frac=0.20)
# Out:
#      PassengerId  Survived  Pclass  \
# 618          619         1       2
# 756          757         0       3
# 338          339         1       3
# 360          361         0       3
# 511          512         0       3
# ..           ...       ...     ...
# 237          238         1       2
# 650          651         0       3
# 759          760         1       1
# 576          577         1       2
# 768          769         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 618                        Becker, Miss. Marion Louise  female   4.0      2
# 756                       Carlsson, Mr. August Sigfrid    male  28.0      0
# 338                              Dahl, Mr. Karl Edwart    male  45.0      0
# 360                                 Skoog, Mr. Wilhelm    male  40.0      1
# 511                                  Webber, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d1 = {"Name": ["Pankaj", "Lisa", "David"], "ID": [1, 2, 3], "Role": ["CEO", "Editor", "Author"]}
df3 = pd.DataFrame(d1)

d2 = {"Name": ["Pankaj"], "ID": [1], "Role": ["CEO"]}
df4=pd.DataFrame(d2)

# %%
df3
# Out:
#      Name  ID    Role
# 0  Pankaj   1     CEO
# 1    Lisa   2  Editor
# 2   David   3  Author

# %%
df4
# Out:
#      Name  ID Role
# 0  Pankaj   1  CEO

# %%
pd.concat([df3,df4])
# Out:
#      Name  ID    Role
# 0  Pankaj   1     CEO
# 1    Lisa   2  Editor
# 2   David   3  Author
# 0  Pankaj   1     CEO

# %%
df5=pd.concat([df3,df4],ignore_index=True)

# %%
d3={"city":['Delhi','Noida','Aligarh','Agra']}
df4=pd.DataFrame(d3)

# %%
df4
# Out:
#       city
# 0    Delhi
# 1    Noida
# 2  Aligarh
# 3     Agra

# %%
df5
# Out:
#      Name  ID    Role
# 0  Pankaj   1     CEO
# 1    Lisa   2  Editor
# 2   David   3  Author
# 3  Pankaj   1     CEO

# %%
df6=pd.concat([df5,df4],axis=1)

# %%
df6.drop_duplicates()
# Out:
#      Name  ID    Role     city
# 0  Pankaj   1     CEO    Delhi
# 1    Lisa   2  Editor    Noida
# 2   David   3  Author  Aligarh
# 3  Pankaj   1     CEO     Agra

# %%
df6.drop_duplicates(subset=['ID'])
# Out:
#      Name  ID    Role     city
# 0  Pankaj   1     CEO    Delhi
# 1    Lisa   2  Editor    Noida
# 2   David   3  Author  Aligarh

# %%
df6.drop_duplicates(subset=['ID'],keep='last')
# Out:
#      Name  ID    Role     city
# 1    Lisa   2  Editor    Noida
# 2   David   3  Author  Aligarh
# 3  Pankaj   1     CEO     Agra

# %%
df6.drop_duplicates(subset=['ID'],keep='last').reset_index()
# Out:
#    index    Name  ID    Role     city
# 0      1    Lisa   2  Editor    Noida
# 1      2   David   3  Author  Aligarh
# 2      3  Pankaj   1     CEO     Agra

# %%
d1 = {"Name": ["Pankaj", "Lisa", "David"], "ID": [1, 2, 3], "Role": ["CEO", "Editor", "Author"]}
df1 = pd.DataFrame(d1)

d2 = {"Name": ["Amit", "Deepak", "Ram"], "ID": [4, 2, 6], "Role": ["CEO", "Sales", "Marketing"]}
df2 = pd.DataFrame(d2)

# %%
df1
# Out:
#      Name  ID    Role
# 0  Pankaj   1     CEO
# 1    Lisa   2  Editor
# 2   David   3  Author

# %%
df2
# Out:
#      Name  ID       Role
# 0    Amit   4        CEO
# 1  Deepak   2      Sales
# 2     Ram   6  Marketing

# %%
#pd.merge(df1,df2,on='ID')
#pd.merge(df1,df2,on='ID',how='left')
#pd.merge(df1,df2,on='ID',how='right')
#pd.merge(df1,df2,on='ID',how='outer')
# Out:
#    Name_x  ID  Role_x  Name_y     Role_y
# 0  Pankaj   1     CEO     NaN        NaN
# 1    Lisa   2  Editor  Deepak      Sales
# 2   David   3  Author     NaN        NaN
# 3     NaN   4     NaN    Amit        CEO
# 4     NaN   6     NaN     Ram  Marketing

# %%
df1=pd.read_csv("/Users/admin/Downloads/Data science with Python 1 2/ratings.dat",
               sep="::",header=None,names=['UserID','MovieID','Rating','Timestamp'])
# Out:
# <ipython-input-88-a9af4fbbb944>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df1=pd.read_csv("/Users/admin/Downloads/Data science with Python 1 2/ratings.dat",

# %%
df2=pd.read_csv("/Users/admin/Downloads/Data science with Python 1 2/users.dat",
               sep="::",header=None,names=['UserID','Genere','Age','Occupation','Zip-code'])
# Out:
# <ipython-input-89-1e5cccdd54eb>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df2=pd.read_csv("/Users/admin/Downloads/Data science with Python 1 2/users.dat",

# %%
df2
# Out:
#       UserID Genere  Age  Occupation Zip-code
# 0          1      F    1          10    48067
# 1          2      M   56          16    70072
# 2          3      M   25          15    55117
# 3          4      M   45           7    02460
# 4          5      M   25          20    55455
# ...      ...    ...  ...         ...      ...
# 6035    6036      F   25          15    32603
# 6036    6037      F   45           1    76006
# 6037    6038      F   56           1    14706
# 6038    6039      F   45           0    01060
# 6039    6040      M   25           6    11106
#
# [6040 rows x 5 columns]

# %%
marge_data=pd.merge(df1,df2,on='UserID')

# %%
marge_data.head()
# Out:
#    UserID  MovieID  Rating  Timestamp Genere  Age  Occupation Zip-code
# 0       1     1193       5  978300760      F    1          10    48067
# 1       1      661       3  978302109      F    1          10    48067
# 2       1      914       3  978301968      F    1          10    48067
# 3       1     3408       4  978300275      F    1          10    48067
# 4       1     2355       5  978824291      F    1          10    48067

# %%
#matplotlib

# %%
import matplotlib.pyplot as plt
import numpy

# %%
#Line plot

# %%
x=np.arange(1,11)

# %%
y=x*2

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.title("Line plot")
plt.xlabel("x-lable")
plt.ylabel("y-lable")
plt.show()

# %%
plt.plot(x,y,linestyle=":",linewidth=10,color='r') #-,--,-.,:
plt.title("Line plot")
plt.xlabel("x-lable")
plt.ylabel("y-lable")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.plot(x,y,color='g',linewidth='8')
plt.plot(x,z,color='r',linewidth='8')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.plot(x,y,color='g',linewidth='8')
plt.plot(x,z,color='r',linewidth='8')
plt.savefig("/Users/admin/Movies/fig.png")

# %%
plt.figure(figsize=(10,7))

plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("befor")

plt.subplot(1,2,2)
plt.plot(x,z)
plt.title("after")
plt.show()

# %%
#Barplot

names=["Sam","Amit","Deepak"]
age=[87,56,27]

# %%
plt.bar(names,age)
plt.title("Bar Plot")
plt.xlabel("Names")
plt.ylabel("Age")
plt.show()

# %%
plt.bar(names,age,color=['red','green','yellow'])
plt.title("Bar Plot")
plt.xlabel("Names")
plt.ylabel("Age")
plt.show()

# %%
plt.barh(names,age,color=['red','green','yellow'])
plt.title("Bar Plot")
plt.xlabel("Age")
plt.ylabel("Name")
plt.show()

# %%
plt.bar(names,age,color=['red','green','yellow'])
plt.text(0,age[0],age[0])
plt.text(1,age[1],age[1])
plt.text(2,age[2],age[2])
plt.title("Bar Plot")
plt.xlabel("Names")
plt.ylabel("Age")
plt.show()

# %%
#scatter plot

x=[10,20,30,40,50,60,70,80,90]
y=[8,1,7,2,0,3,7,8,9]

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.scatter(x,y,color='r',marker='s',linewidth=3,edgecolors='g') #s,^,*,o
plt.show()
